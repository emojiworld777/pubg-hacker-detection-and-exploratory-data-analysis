# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r"C:\lpu\semester 5\eda and sql\PUBG.csv")

# %%
df.head(5)
# Out:
#      player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 0      BreakNeck        4405                 3.14          17.65
# 1      Blackwalk        8199                 4.41          18.18
# 2  mercedes_benz        4454                 3.60           0.00
# 3           DORA        7729                14.00          50.00
# 4        n2tstar           0                10.50          33.33
#
#    solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# 0           18469.14                 17          3                0.83
# 1           33014.86                 33          6                0.36
# 2            4330.44                  5          0                0.00
# 3           13421.82                  8          4                0.67
# 4            9841.04                  6          2                0.40
#
#    solo_Top10s  solo_Top10Ratio  ...  squad_RideDistance  squad_MoveDistance  \
# ...

# %%
df.shape
# Out:
# (87898, 152)

# %%
df.tail()
# Out:
#          player_name  tracker_id  solo_KillDeathRatio  solo_WinRatio  \
# 87893      SaikoMene       87710                 1.05           0.00
# 87894        KARUKOR       22783                 1.61           4.65
# 87895      Dertydann      178547                 1.00           0.00
# 87896       Neferhor      126589                 5.10          16.67
# 87897  pepperedangus       66362                 0.83           1.38
#
#        solo_TimeSurvived  solo_RoundsPlayed  solo_Wins  solo_WinTop10Ratio  \
# 87893           48273.92                 62          0                0.00
# 87894           49006.75                 43          2                0.22
# 87895           14272.20                 16          0                0.00
# 87896           58518.86                 48          8                0.44
# 87897          198473.81                217          3                0.03
#
#        solo_Top10s  solo_Top10Ratio  ...  squad_RideDistance  \
# ...

# %%
df.isnull().sum()
# Out:
# player_name            0
# tracker_id             0
# solo_KillDeathRatio    0
# solo_WinRatio          0
# solo_TimeSurvived      0
#                       ..
# squad_Heals            0
# squad_Revives          0
# squad_Boosts           0
# squad_DamageDealt      0
# squad_DBNOs            0
# Length: 152, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87898 entries, 0 to 87897
# Columns: 152 entries, player_name to squad_DBNOs
# dtypes: float64(83), int64(68), object(1)
# memory usage: 101.9+ MB

# %%
df.describe()
# Out:
#           tracker_id  solo_KillDeathRatio  solo_WinRatio  solo_TimeSurvived  \
# count   87898.000000         87898.000000   87898.000000       8.789800e+04
# mean   110794.357050             1.865855       5.017506       6.971571e+04
# std     63648.581759             1.776301      10.077138       8.040861e+04
# min         0.000000             0.000000       0.000000       7.610000e+01
# 25%     51925.250000             1.030000       0.000000       1.789705e+04
# 50%    112705.500000             1.470000       2.000000       4.517333e+04
# 75%    164879.750000             2.140000       5.560000       9.246264e+04
# max    222490.000000           100.000000     100.000000       1.521200e+06
#
#        solo_RoundsPlayed     solo_Wins  solo_WinTop10Ratio   solo_Top10s  \
# count       87898.000000  87898.000000        87898.000000  87898.000000
# mean           79.275342      2.080093            0.179251     12.106282
# ...

# %%
def printinfo():
    temp = pd.DataFrame(index=df.columns)
    temp['dataType'] = df.dtypes
    temp['nullCount'] = df.isnull().sum()
    temp['uniqueCount'] = df.nunique()
    return temp
printinfo()
# Out:
#                     dataType  nullCount  uniqueCount
# player_name           object          0        87897
# tracker_id             int64          0        87898
# solo_KillDeathRatio  float64          0          897
# solo_WinRatio        float64          0         1453
# solo_TimeSurvived    float64          0        87583
# ...                      ...        ...          ...
# squad_Heals            int64          0         1962
# squad_Revives          int64          0          293
# squad_Boosts           int64          0         1470
# squad_DamageDealt    float64          0        87193
# squad_DBNOs            int64          0         1335
#
# [152 rows x 3 columns]

# %%
x = df['solo_KillDeathRatio'].value_counts().index
y =df['player_name'].value_counts()
xaxis = []
yaxis = []
for i in range(len(x)):
    xaxis.append(x[i])
    yaxis.append(y[i])

plt.figure(figsize = (25,18))
plt.xlabel('solo_KillDeathRatio')
plt.ylabel('player_name')
graph = sns.barplot(x =xaxis,y = yaxis,palette ='husl')
graph.set_title('Top solo player based on there killdeath ration')
# Out:
# Text(0.5, 1.0, 'Top solo player based on there killdeath ration')

# %%
sns.histplot(df['solo_KillDeathRatio'], kde = True)
plt.title('Solo Kill_death_ratio Distribution')
plt.xlabel('Kill_death_ratio solo')
plt.ylabel('Counts')
plt.show()

# %%
# Solo Kill Distribution
kill = df['solo_Kills']
plt.hist(kill,bins = 100)
plt.xlabel("solo kill counts")
plt.ylabel("kill frequency")
plt.title('Solo Kill Distribution')
plt.show()

# %%
# relation between kill and survival time
surv_time = df['solo_TimeSurvived']
corrx = np.corrcoef(kill,surv_time)[0,1]
print(corrx)
df = pd.DataFrame({'Kill Counts': kill, 'Survival Time': surv_time})
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap: Kill Counts vs. Survival Time")
plt.show()
# Out:
# 0.8261760877518648

# %%
sns.jointplot(x= kill,y=surv_time,kind = 'hex')
plt.xlabel('kill counts')
plt.ylabel('survival time')
plt.title('Relation between Kills And Survival Time')
plt.show()

# %%
headshotratio = df['solo_HeadshotKillsPg']/df['solo_KIlls']
print(heatshotratio.mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'solo_HeadshotKillsPg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
survival_time = df['solo_TimeSurvived']  # Replace 'solo_TimeSurvived' with the appropriate column name
plt.hist(survival_time, bins=10)
plt.xlabel("Survival Time")
plt.ylabel("Frequency")
plt.title("Survival Time Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'solo_TimeSurvived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
